# %%
import pandas as pd # Importing libraries
import numpy as np

# %%
df = pd.read_csv('master_data.csv')
df.drop(['Unnamed: 0','Job-id','Company-ID','Job_description'],axis=1, inplace=True)
df
# Out:
#                  Company                                           Job_name  \
# 0            MedTourEasy                                  R Analyst Trainee
# 1       Infoparks Kerala                       Immediate hiring - AR Caller
# 2       Infoparks Kerala                  QA Tester - Manual and Automation
# 3          GE Healthcare                                  Software Engineer
# 4               Qualcomm                                    Engineer, Staff
# ..                   ...                                                ...
# 411      Larsen & Toubro                                    Project Manager
# 412  Aster DM Healthcare  Staff Nurse. Nursing.Aster Mother Hospital, Ar...
# 413      Larsen & Toubro                              Project Site Engineer
# 414  Aster DM Healthcare  Deputy Manager.International Marketing.Aster C...
# 415       Mahindra Group                                    Senior Engineer
#
# ...

# %%
for col in ['involvement','Applicants','Level']:
    df[col] = df[col].astype('str').apply(lambda x: x.strip())

# %% [markdown]
# # Details Table:

# %%
details_table = df[['involvement','Applicants','Level']]

# %%
details_table.drop_duplicates(inplace=True)
# Out:
# C:\Users\bjami\AppData\Local\Temp\ipykernel_13640\812160439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details_table.drop_duplicates(inplace=True)

# %%
details_table.reset_index(drop=True, inplace=True)

# %%
details_table.reset_index(inplace=True)

# %%
details_table.columns=['Details_ID', 'involvement', 'Applicants', 'Level']

# %%
details_table.Details_ID = details_table.Details_ID.astype('str').apply(lambda x: 'D-'+x )
# Out:
# C:\Users\bjami\AppData\Local\Temp\ipykernel_13640\1251207219.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details_table.Details_ID = details_table.Details_ID.astype('str').apply(lambda x: 'D-'+x )

# %%
details_table
# Out:
#     Details_ID involvement Applicants        Level
# 0          D-0  Internship         14   Internship
# 1          D-1   Full-time          3  Entry level
# 2          D-2   Full-time         18  Entry level
# 3          D-3   Full-time         46  Entry level
# 4          D-4   Full-time         11  Entry level
# ..         ...         ...        ...          ...
# 168      D-168  Internship         12   Internship
# 169      D-169   Full-time        150   Internship
# 170      D-170   Full-time         48    Associate
# 171      D-171   Full-time         91  Entry level
# 172      D-172   Full-time         59  Entry level
#
# [173 rows x 4 columns]

# %% [markdown]
# Left joining details_table on the main DF:

# %%
new_df= pd.merge(df,details_table, how='left',on=['involvement', 'Applicants', 'Level'])

# %%
new_df
# Out:
#                  Company                                           Job_name  \
# 0            MedTourEasy                                  R Analyst Trainee
# 1       Infoparks Kerala                       Immediate hiring - AR Caller
# 2       Infoparks Kerala                  QA Tester - Manual and Automation
# 3          GE Healthcare                                  Software Engineer
# 4               Qualcomm                                    Engineer, Staff
# ..                   ...                                                ...
# 411      Larsen & Toubro                                    Project Manager
# 412  Aster DM Healthcare  Staff Nurse. Nursing.Aster Mother Hospital, Ar...
# 413      Larsen & Toubro                              Project Site Engineer
# 414  Aster DM Healthcare  Deputy Manager.International Marketing.Aster C...
# 415       Mahindra Group                                    Senior Engineer
#
# ...

# %% [markdown]
# # Company table:

# %%
company_table = df[['Company','Industry','Employees','Followers']]

# %%
company_table.drop_duplicates(inplace=True) # Removing duplicate rows from company_table
company_table.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\bjami\AppData\Local\Temp\ipykernel_13640\2177156453.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_table.drop_duplicates(inplace=True)

# %%
company_table
# Out:
#                                   Company  \
# 0                             MedTourEasy
# 1                        Infoparks Kerala
# 2                           GE Healthcare
# 3                                Qualcomm
# 4                    Global Savings Group
# ..                                    ...
# 161                         Deutsche Bahn
# 162                           KuehneNagel
# 163  EduMetrix Learning Solutions Pvt Ltd
# 164                    Cerner Corporation
# 165                   Aster DM Healthcare
#
#                                               Industry  Employees Followers
# 0                            Hospitals and Health Care        350     18054
# 1                        IT Services and IT Consulting      10001     57465
# 2                            Hospitals and Health Care      10001   1897527
# 3                                    Wireless Services      10001   1156557
# ...

# %%
company_table.reset_index(inplace=True)

# %%
company_table
# Out:
#      index                               Company  \
# 0        0                           MedTourEasy
# 1        1                      Infoparks Kerala
# 2        2                         GE Healthcare
# 3        3                              Qualcomm
# 4        4                  Global Savings Group
# ..     ...                                   ...
# 161    161                         Deutsche Bahn
# 162    162                           KuehneNagel
# 163    163  EduMetrix Learning Solutions Pvt Ltd
# 164    164                    Cerner Corporation
# 165    165                   Aster DM Healthcare
#
#                                               Industry  Employees Followers
# 0                            Hospitals and Health Care        350     18054
# 1                        IT Services and IT Consulting      10001     57465
# 2                            Hospitals and Health Care      10001   1897527
# ...

# %%
company_table.columns=['Company_ID', 'Company', 'Industry', 'Employees', 'Followers']
company_table.Company_ID= company_table.Company_ID.astype('str').apply(lambda x: 'C-'+x)
# Out:
# C:\Users\bjami\AppData\Local\Temp\ipykernel_13640\22331294.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   company_table.Company_ID= company_table.Company_ID.astype('str').apply(lambda x: 'C-'+x)

# %%
company_table
# Out:
#     Company_ID                               Company  \
# 0          C-0                           MedTourEasy
# 1          C-1                      Infoparks Kerala
# 2          C-2                         GE Healthcare
# 3          C-3                              Qualcomm
# 4          C-4                  Global Savings Group
# ..         ...                                   ...
# 161      C-161                         Deutsche Bahn
# 162      C-162                           KuehneNagel
# 163      C-163  EduMetrix Learning Solutions Pvt Ltd
# 164      C-164                    Cerner Corporation
# 165      C-165                   Aster DM Healthcare
#
#                                               Industry  Employees Followers
# 0                            Hospitals and Health Care        350     18054
# 1                        IT Services and IT Consulting      10001     57465
# 2                            Hospitals and Health Care      10001   1897527
# ...

# %% [markdown]
# Left Joining company_table on the main data frame:

# %%
new_df=pd.merge(new_df,company_table,how='left', on=['Company', 'Industry', 'Employees', 'Followers'])

# %% [markdown]
# # Job table:

# %%
new_df
# Out:
#                  Company                                           Job_name  \
# 0            MedTourEasy                                  R Analyst Trainee
# 1       Infoparks Kerala                       Immediate hiring - AR Caller
# 2       Infoparks Kerala                  QA Tester - Manual and Automation
# 3          GE Healthcare                                  Software Engineer
# 4               Qualcomm                                    Engineer, Staff
# ..                   ...                                                ...
# 411      Larsen & Toubro                                    Project Manager
# 412  Aster DM Healthcare  Staff Nurse. Nursing.Aster Mother Hospital, Ar...
# 413      Larsen & Toubro                              Project Site Engineer
# 414  Aster DM Healthcare  Deputy Manager.International Marketing.Aster C...
# 415       Mahindra Group                                    Senior Engineer
#
# ...

# %%
job_table = new_df[['Job_name','Location','Company_ID','Details_ID',]]

# %%
job_table.drop_duplicates(inplace=True)
job_table.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\bjami\AppData\Local\Temp\ipykernel_13640\3281721018.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   job_table.drop_duplicates(inplace=True)

# %%
job_table.reset_index(inplace=True)

# %%
job_table.columns=['Job_ID', 'Job_name', 'Location', 'Company_ID', 'Details_ID']
job_table.Job_ID = job_table.Job_ID.astype('str').apply(lambda x: 'J-'+x)
# Out:
# C:\Users\bjami\AppData\Local\Temp\ipykernel_13640\3239804967.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   job_table.Job_ID = job_table.Job_ID.astype('str').apply(lambda x: 'J-'+x)

# %%
job_table
# Out:
#     Job_ID                                           Job_name  \
# 0      J-0                                  R Analyst Trainee
# 1      J-1                       Immediate hiring - AR Caller
# 2      J-2                  QA Tester - Manual and Automation
# 3      J-3                                  Software Engineer
# 4      J-4                                    Engineer, Staff
# ..     ...                                                ...
# 404  J-404                                    Project Manager
# 405  J-405  Staff Nurse. Nursing.Aster Mother Hospital, Ar...
# 406  J-406                              Project Site Engineer
# 407  J-407  Deputy Manager.International Marketing.Aster C...
# 408  J-408                                    Senior Engineer
#
#                         Location Company_ID Details_ID
# 0    Bengaluru, Karnataka, India        C-0        D-0
# 1           Kochi, Kerala, India        C-1        D-1
# ...

# %% [markdown]
# Left joining job_table on new_df:

# %%
new_df = pd.merge(new_df,job_table,how='left', on=['Job_name', 'Location', 'Company_ID', 'Details_ID'])

# %%
new_df
# Out:
#                  Company                                           Job_name  \
# 0            MedTourEasy                                  R Analyst Trainee
# 1       Infoparks Kerala                       Immediate hiring - AR Caller
# 2       Infoparks Kerala                  QA Tester - Manual and Automation
# 3          GE Healthcare                                  Software Engineer
# 4               Qualcomm                                    Engineer, Staff
# ..                   ...                                                ...
# 411      Larsen & Toubro                                    Project Manager
# 412  Aster DM Healthcare  Staff Nurse. Nursing.Aster Mother Hospital, Ar...
# 413      Larsen & Toubro                              Project Site Engineer
# 414  Aster DM Healthcare  Deputy Manager.International Marketing.Aster C...
# 415       Mahindra Group                                    Senior Engineer
#
# ...

# %% [markdown]
# # Converting every DataFrame to csv files

# %%
new_df.to_csv('new_df.csv')
company_table.to_csv('company_table.csv')
job_table.to_csv('job_table.csv')
details_table.to_csv('details_table.csv')
