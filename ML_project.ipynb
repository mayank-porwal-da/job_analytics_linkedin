# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:/Users/mayan/Downloads/new_df.csv")
df
# Out:
#     Job_ID              Company  \
# 0      J-0          MedTourEasy
# 1      J-1     Infoparks Kerala
# 2      J-2     Infoparks Kerala
# 3      J-3        GE Healthcare
# 4      J-4             Qualcomm
# ..     ...                  ...
# 410  J-404      Larsen & Toubro
# 411  J-405  Aster DM Healthcare
# 412  J-406      Larsen & Toubro
# 413  J-407  Aster DM Healthcare
# 414  J-408       Mahindra Group
#
#                                               Job_name  \
# 0                                    R Analyst Trainee
# 1                         Immediate hiring - AR Caller
# 2                    QA Tester - Manual and Automation
# 3                                    Software Engineer
# 4                                      Engineer, Staff
# ..                                                 ...
# 410                                    Project Manager
# 411  Staff Nurse. Nursing.Aster Mother Hospital, Ar...
# 412                              Project Site Engineer
# ...

# %%
df.dtypes
# Out:
# Job_ID         object
# Company        object
# Job_name       object
# Location       object
# Applicants      int64
# involvement    object
# Level          object
# Employees       int64
# Link           object
# Followers       int64
# Industry       object
# skills         object
# merged         object
# Company_ID     object
# Details_ID     object
# dtype: object

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(4)

# %%
df['Followers']=df['Followers'].drop([328])

# %%
df['Followers'].unique()
# Out:
# array([  18054,   57465, 1897527, 1156557,   11447, 1312733, 3570127,
#         387800, 3923020, 3151200, 6462755,    9491,  121805,  235506,
#         836404,   42223,     453,  795838, 2044378, 6993519,    3331,
#        2248950, 1686546,   18204, 2167232,    2126, 1372595, 1619531,
#        5147832, 1603730,  458788,    3064,   91623,   18107, 1357755,
#         159279,  576519,   22168,  670067,  120007,   42233,    1519,
#           2420,  194224, 3547179,  456707,    1611, 1475765, 3032028,
#         190868,  790457,     146,    4225, 1499846,   21107,  976867,
#            606, 1509790,   45905, 1719130, 2596262, 6073827,  153880,
#         306699,    8921,   58879,   15265,    3055,  435555, 2305276,
#        6927538,     597, 1471678,   20011,  210938, 4308116,   68618,
#         233509,    1197, 4798788,  535078,  733242,   23910,  691242,
#          83948, 1083086,  407662, 6510006, 3454745, 4641861,  297095,
# ...

# %%
df=df.dropna()

# %%
new_df=df[['Followers','Employees']]

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# Job-id             0
# Company            0
# Company-ID         0
# Job_name           0
# Location           0
# Applicants         0
# involvement        0
# Level              0
# Employees          0
# Link               0
# Job_description    0
# Followers          0
# Industry           0
# skills             0
# dtype: int64

# %%
kmeans.fit(new_df)
# Out:
# KMeans(n_clusters=4)

# %%
cluster_value=kmeans.predict(new_df)

# %%
df["clusters"]=cluster_value

# %%
df
# Out:
#     Job_ID              Company  \
# 0      J-0          MedTourEasy
# 1      J-1     Infoparks Kerala
# 2      J-2     Infoparks Kerala
# 3      J-3        GE Healthcare
# 4      J-4             Qualcomm
# ..     ...                  ...
# 410  J-404      Larsen & Toubro
# 411  J-405  Aster DM Healthcare
# 412  J-406      Larsen & Toubro
# 413  J-407  Aster DM Healthcare
# 414  J-408       Mahindra Group
#
#                                               Job_name  \
# 0                                    R Analyst Trainee
# 1                         Immediate hiring - AR Caller
# 2                    QA Tester - Manual and Automation
# 3                                    Software Engineer
# 4                                      Engineer, Staff
# ..                                                 ...
# 410                                    Project Manager
# 411  Staff Nurse. Nursing.Aster Mother Hospital, Ar...
# 412                              Project Site Engineer
# ...

# %%
df.to_csv('C:/Users/mayan/Downloads/master_data_file.csv')
